# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("raw_data.csv")

# %%
df.head()
# Out:
#   customer_id  age  gender  annual_income_k$  spending_score
# 0       C0001   58  Female                71            38.5
# 1       C0002   25  Female               139            86.0
# 2       C0003   19    Male                71            37.6
# 3       C0004   65    Male                84            63.0
# 4       C0005   35    Male               126            74.3

# %%
df.tail()
# Out:
#     customer_id  age  gender  annual_income_k$  spending_score
# 295       C0296   24    Male                28            16.9
# 296       C0297   60  Female                67            22.0
# 297       C0298   45  Female                83            54.0
# 298       C0299   40  Female                48            19.8
# 299       C0300   45  Female                88            42.7

# %%
df.shape
# Out:
# (300, 5)

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'annual_income_k$', 'spending_score'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       300 non-null    object
#  1   age               300 non-null    int64
#  2   gender            300 non-null    object
#  3   annual_income_k$  300 non-null    int64
#  4   spending_score    300 non-null    float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 11.8+ KB

# %%
df.isnull().sum()                   #missing valuee
# Out:
# customer_id         0
# age                 0
# gender              0
# annual_income_k$    0
# spending_score      0
# dtype: int64

# %%
df.duplicated().sum()             # duplicate rows
# Out:
# 0

# %%
df['spending_category'] = pd.cut(                    #spending category (add new coloumn)
    df['spending_score'],
    bins = 3,
    labels = ['Low', 'Medium', 'High']
)

# %%
df
# Out:
#     customer_id  age  gender  annual_income_k$  spending_score  \
# 0         C0001   58  Female                71            38.5
# 1         C0002   25  Female               139            86.0
# 2         C0003   19    Male                71            37.6
# 3         C0004   65    Male                84            63.0
# 4         C0005   35    Male               126            74.3
# ..          ...  ...     ...               ...             ...
# 295       C0296   24    Male                28            16.9
# 296       C0297   60  Female                67            22.0
# 297       C0298   45  Female                83            54.0
# 298       C0299   40  Female                48            19.8
# 299       C0300   45  Female                88            42.7
#
#     spending_category
# 0              Medium
# 1                High
# 2              Medium
# 3              Medium
# 4                High
# ..                ...
# 295               Low
# ...

# %%
'''Thise feature capture how aggressively a customer spends
   realtive to thier income and age'''

df['Spending_Intensity'] = (
    df['spending_score'] +
    df['annual_income_k$'] / df[ 'age']
)

# %%
df.head()
# Out:
#   customer_id  age  gender  annual_income_k$  spending_score  \
# 0       C0001   58  Female                71            38.5
# 1       C0002   25  Female               139            86.0
# 2       C0003   19    Male                71            37.6
# 3       C0004   65    Male                84            63.0
# 4       C0005   35    Male               126            74.3
#
#   spending_category  Spending_Intensity
# 0            Medium           39.724138
# 1              High           91.560000
# 2            Medium           41.336842
# 3            Medium           64.292308
# 4              High           77.900000

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'annual_income_k$', 'spending_score',
#        'spending_category', 'Spending_Intensity'],
#       dtype='object')

# %%
df.to_csv("cleaned_data.csv", index = False)
